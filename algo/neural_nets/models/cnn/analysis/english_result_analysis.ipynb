# %% [markdown]
# This file contains the error analysis for English task

# %%
import pandas as pd
from visualisation import plot_word_cloud

full = pd.read_csv("temp/data/result.tsv", sep='\t')

full[:10]
# Out:
#       id                                              tweet subtask_a  \
# 0  27574  @USER @USER @USER Is she a memeber of antifa? ...       NOT
# 1  63087    @USER @USER How about gun control for starters?       NOT
# 2  35542          @USER And Hillary is president!  LOL! URL       NOT
# 3  73370  @USER @USER @USER Our African 🇺🇸 friends don't...       NOT
# 4  38273  @USER @USER You are very talented Clare. What ...       NOT
# 5  64878  @USER @USER ‘Fake News’ is term used RATHER th...       NOT
# 6  33048  @USER another judge that first blames the tool...       OFF
# 7  98457               Time to visit Banbury Team!  URL URL       NOT
# 8  73281  *SCREAMS* SHE IS SO CUTE WHEN SHE DOES THIS!!!...       NOT
# 9  16048                             @USER That’s my place😩       NOT
#
#   subtask_b subtask_c  encoded_subtask_a  predictions
# 0       NaN       NaN                  0            0
# 1       NaN       NaN                  0            0
# ...

# %%
FALSE_POSITIVES = full[(full['encoded_subtask_a'] == 0) & (full['predictions'] == 1)]
FALSE_NEGATIVES = full[(full['encoded_subtask_a'] == 1) & (full['predictions'] == 0)]

# %% [markdown]
# False Positives

# %%
plot_word_cloud(FALSE_POSITIVES)
# Out:
# /home/tharindu/Projects/OffensEval_2020/visualisation.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tweet"] = df["tweet"].apply(lambda x: clean_text(x))
# /home/tharindu/Projects/OffensEval_2020/visualisation.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tweet"] = df["tweet"].apply(lambda x: clean_numbers(x))
# /home/tharindu/Projects/OffensEval_2020/visualisation.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# False Negatives

# %%
plot_word_cloud(FALSE_NEGATIVES)
